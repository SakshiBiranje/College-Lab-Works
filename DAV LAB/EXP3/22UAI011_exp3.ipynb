# %%
import pandas as pd

# %%
df = pd.read_csv("input_file.csv")

# %%
print("Original Dataset:")
print(df)
# Out:
# Original Dataset:
#    ProductID     Category ProductName    Price  Stock
# 0          1  Electronics  Smartphone  15000.0   25.0
# 1          2  Electronics      Laptop      NaN   10.0
# 2          3     Clothing         NaN    800.0  100.0
# 3          4     Clothing       Jeans   1500.0    NaN
# 4          5    Groceries        Rice     50.0  500.0
# 5          6    Groceries         NaN     40.0  300.0
# 6          7  Electronics  Headphones      NaN   45.0
# 7          8     Clothing      Jacket   2500.0   20.0
# 8          9    Groceries         Tea    120.0    NaN
# 9         10  Electronics  Smartwatch   5000.0   30.0

# %%
print("\nMissing values in each column:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
# ProductID      0
# Category       0
# ProductName    2
# Price          2
# Stock          2
# dtype: int64

# %%
df_dropped = df.dropna()
print("\nDataFrame after dropping rows with missing values:")
print(df_dropped)
# Out:
# DataFrame after dropping rows with missing values:
#    ProductID     Category ProductName    Price  Stock
# 0          1  Electronics  Smartphone  15000.0   25.0
# 4          5    Groceries        Rice     50.0  500.0
# 7          8     Clothing      Jacket   2500.0   20.0
# 9         10  Electronics  Smartwatch   5000.0   30.0

# %%
df_filled_constant = df.fillna(0)
print("\nDataFrame after filling missing values with 0:")
print(df_filled_constant)
# Out:
# DataFrame after filling missing values with 0:
#    ProductID     Category ProductName    Price  Stock
# 0          1  Electronics  Smartphone  15000.0   25.0
# 1          2  Electronics      Laptop      0.0   10.0
# 2          3     Clothing           0    800.0  100.0
# 3          4     Clothing       Jeans   1500.0    0.0
# 4          5    Groceries        Rice     50.0  500.0
# 5          6    Groceries           0     40.0  300.0
# 6          7  Electronics  Headphones      0.0   45.0
# 7          8     Clothing      Jacket   2500.0   20.0
# 8          9    Groceries         Tea    120.0    0.0
# 9         10  Electronics  Smartwatch   5000.0   30.0

# %%
if 'Price' in df.columns:
    df['Price'] = df['Price'].fillna(df['Price'].mean())
print("\nDataFrame after filling 'Price' column with its mean value:")
print(df)
# Out:
# DataFrame after filling 'Price' column with its mean value:
#    ProductID     Category ProductName     Price  Stock
# 0          1  Electronics  Smartphone  15000.00   25.0
# 1          2  Electronics      Laptop   3126.25   10.0
# 2          3     Clothing         NaN    800.00  100.0
# 3          4     Clothing       Jeans   1500.00    NaN
# 4          5    Groceries        Rice     50.00  500.0
# 5          6    Groceries         NaN     40.00  300.0
# 6          7  Electronics  Headphones   3126.25   45.0
# 7          8     Clothing      Jacket   2500.00   20.0
# 8          9    Groceries         Tea    120.00    NaN
# 9         10  Electronics  Smartwatch   5000.00   30.0

# %%
df_ffill = df.fillna(method='ffill')
print("\nDataFrame after forward fill:")
print(df_ffill)
# Out:
# <ipython-input-10-b3e69afc5c91>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_ffill = df.fillna(method='ffill')
# DataFrame after forward fill:
#    ProductID     Category ProductName     Price  Stock
# 0          1  Electronics  Smartphone  15000.00   25.0
# 1          2  Electronics      Laptop   3126.25   10.0
# 2          3     Clothing      Laptop    800.00  100.0
# 3          4     Clothing       Jeans   1500.00  100.0
# 4          5    Groceries        Rice     50.00  500.0
# 5          6    Groceries        Rice     40.00  300.0
# 6          7  Electronics  Headphones   3126.25   45.0
# 7          8     Clothing      Jacket   2500.00   20.0
# 8          9    Groceries         Tea    120.00   20.0
# 9         10  Electronics  Smartwatch   5000.00   30.0

# %%
print("\nCleaned DataFrame (final view):")
print(df.head())
# Out:
# Cleaned DataFrame (final view):
#    ProductID     Category ProductName     Price  Stock
# 0          1  Electronics  Smartphone  15000.00   25.0
# 1          2  Electronics      Laptop   3126.25   10.0
# 2          3     Clothing         NaN    800.00  100.0
# 3          4     Clothing       Jeans   1500.00    NaN
# 4          5    Groceries        Rice     50.00  500.0

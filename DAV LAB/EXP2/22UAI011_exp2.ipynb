# %%
import pandas as pd

# %%
df = pd.read_csv("input_file.csv")

# %%
print("\nFirst 5 rows of the dataset:")
print(df.head())
# Out:
# First 5 rows of the dataset:
#    ProductID     Category ProductName  Price  Stock
# 0          1  Electronics  Smartphone  15000     25
# 1          2  Electronics      Laptop  55000     10
# 2          3     Clothing     T-Shirt    800    100
# 3          4     Clothing       Jeans   1500     60
# 4          5    Groceries        Rice     50    500

# %%
print("\nShape of the DataFrame (rows, columns):")
print(df.shape)
# Out:
# Shape of the DataFrame (rows, columns):
# (14, 5)

# %%
print("\nData types and non-null values:")
print(df.info())
# Out:
# Data types and non-null values:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ProductID    14 non-null     int64
#  1   Category     14 non-null     object
#  2   ProductName  14 non-null     object
#  3   Price        14 non-null     int64
#  4   Stock        14 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 520.0+ bytes
# None

# %%
print("\nData types and non-null values:")
print(df.info())
# Out:
# Data types and non-null values:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ProductID    14 non-null     int64
#  1   Category     14 non-null     object
#  2   ProductName  14 non-null     object
#  3   Price        14 non-null     int64
#  4   Stock        14 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 520.0+ bytes
# None

# %%
column_name = 'Category'  # Example column
if column_name in df.columns:
    print(f"\nValue counts for the column '{column_name}':")
    print(df[column_name].value_counts())
else:
    print(f"\nColumn '{column_name}' not found in dataset. Please update the column name.")
# Out:
# Value counts for the column 'Category':
# Category
# Electronics    5
# Clothing       5
# Groceries      4
# Name: count, dtype: int64
